# %% [markdown]
# # Python OOPs Questions
#
# 1. What is Object-Oriented Programming (OOP)
#
# -> Object-Oriented Programming is like building your program out of little story-characters that know how to behave, remember things, and interact with each other. Instead of writing everything as one long script, you create well-behaved “objects” that each have a clear role in the tale.
#
# 2.  What is a class in OOP
#
# ->A class in Object-Oriented Programming is the blueprint used to create objects. It’s the design, the template, the master plan. Objects are the actual things made from that plan.
#
# .Attributes (data/variables)
#
# .Methods (functions/behaviors)
#
#
# 3. What is an object in oop
#
#
# -> An object in OOP is the living, breathing (well, digitally) result created from a class.
# If a class is the blueprint, then an object is the finished house you can walk into
#
# .Actual data
#
# .Functionality
#
#
# 4. What is the difference between abstraction and encapsulation
#
# ->Abstraction and encapsulation are like two friendly guardians of clean code. They work together but protect different things inside your program’s little universe.
#
# Abstraction
#
# Abstraction is about showing only what’s necessary and hiding the rest.
# Think of it as a well-behaved interface that says,
# "Use me without worrying about my internal gears."
#
#  Focus: Hiding complexity
#
# Purpose: Makes the user see only the important features
#
#  Example:
# When you press the start button in a car, you don’t care how fuel mixes with air or how circuits chirp to life. You only see “Car starts.”
#
#
# Encapsulation
#
# Encapsulation is about wrapping data and methods into a single unit (class) and controlling access to that data.
# It’s like keeping important things in a vault and giving access through controlled doors.
#
# Focus: Protecting data
#
# Purpose: Prevents direct, unsafe access to internal details
#
# Tools:
#
# Private variables
#
# Getters & setters
#
# 5. What are dunder methods in Python
#
#
# -> Dunder methods are Python’s secret trapdoors, marked with double underscores on both sides. They let your objects behave like native Python features, almost as if the class is learning ancient spells
#
#
# 6.  Explain the concept of inheritance in OOP
#
# ->Inheritance in OOP is the art of letting one class borrow the strengths of another so it doesn’t have to start life from scratch. It’s like a new character in a story receiving a well-packed trunk of abilities, traits, and tools from an older character.
#
#
# 7. What is polymorphism in OOP
#
# -> Polymorphism is the elegant talent in OOP that lets the same action take different forms depending on who performs it. It’s like giving a single word to several characters and watching each one express it in their own voice.
#
#
# 8. How is encapsulation achieved in Python
#
# -> Encapsulation in Python is achieved by protecting data inside a class and offering controlled doorways to access it.
#
# 9What is a constructor in Python
#
# -> A constructor is a special method named __init__ that runs automatically when an object is created from a class.
#
# 10. What are class and static methods in Python
#
# ->
# - A class method is tied to the class itself, not to individual objects.
#
# - A static method is like a quiet helper that sits inside the class but doesn’t depend on the class or any object.
#
# 11. What is method overloading in Python
#
# ->Method overloading in Python is a bit of a curious creature. In languages like Java or C++, you can define multiple methods with the same name but different parameters. Python, however, prefers to travel light and doesn’t support true method overloading in that strict sense.
#
#
# 12.  What is method overriding in OOP
#
# -> Method overriding is the moment when a child class looks at a method inherited from its parent and says,
# “I appreciate the gift, but I’ll use my own version.
#
# 13.  What is a property decorator in Python
#
# -> A property decorator in Python is a graceful way to turn a method into an attribute-like interface. It lets your class expose data cleanly while still keeping full control behind the scenes.
#
# 14.  Why is polymorphism important in OOP
#
# -> Polymorphism is important in OOP because it lets your code behave like a well-trained orchestra: one signal, many instruments responding in their own beautiful way.
#
# 15. What is an abstract class in Python
#
# -> An abstract class in Python is like a blueprint that refuses to be built directly. It lays down the rules, the skeleton, the “must-have” behaviors, but leaves the actual details for its children to fill in.
#
# 16. What are the advantages of OOP
#
# ->Object-Oriented Programming comes with a basket of advantages that make software feel organized, flexible, and expandable.
#
# 17. What is the difference between a class variable and an instance variable
#
# -> A class variable and an instance variable are like two types of belongings inside a class:
# one belongs to every object together, and the other belongs to each object individually.
#
# 18. What is multiple inheritance in Python
#
# ->Multiple inheritance in Python is when a class learns its skills from more than one parent. It’s like a character in a story raised by two different masters, inheriting techniques from both.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#
#
# -> __str__ and __repr__ are Python’s two storytelling methods.
# They decide how your object introduces itself — whether it speaks casually to users or formally to developers.
#
# 20. What is the significance of the ‘super()’ function in Python
#
#
# -> super() in Python is like calling your parent class on a cosmic hotline. It lets a child class tap into its parent’s powers without naming the parent directly, keeping everything clean and future-proof.
#
#
# 21. What is the significance of the __del__ method in Python
#
# -> __del__ is Python’s quiet curtain-closing method. It’s called when an object is about to disappear, giving it one last moment to tidy up before it vanishes from memory.
#
# 22. What is the difference between @staticmethod and @classmethod in Python
#
# -> 1. @staticmethod — The method with no strings attached
#
# A staticmethod doesn't take self or cls.
#
# It behaves like a regular function that simply lives inside a class for organizational convenience.
#
# Key points
#
# No access to instance (self)
#
# No access to class (cls)
#
# Pure utility function
#
# - @classmethod — The method that knows the class
#
# A classmethod takes cls as the first argument.
#
# It works with the class itself, not an individual object.
#
# Key points
#
# Has access to class variables
#
# Can modify class state
#
# Often used as factory methods
#
#
# 23. How does polymorphism work in Python with inheritance
#
#
# ->Polymorphism in Python becomes especially lively when inheritance enters the scene.
# A parent class offers a method, and each child class reshapes that method in its own voice. When you call the method on different objects, each object responds according to its own identity, even though the call looks the same.
#
# 24. What is method chaining in Python OOP
#
# ->Method chaining in Python is a smooth conversational dance between methods, where each one politely hands the object back so the next method can continue the story.
#
# 25. What is the purpose of the __call__ method in Python
#
# ->__call__ gives an object the power to behave like a function.
# Once this method is defined, you can call the object itself using parentheses, and it responds just like a callable creature.

# %% [markdown]
# #Practical Questions

# %% [markdown]
#  1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("This animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

 Abstract Class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


 Derived Class 1
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius


Derived Class 2
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type


class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = bran

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Some birds can fly")


class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")


class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they swim gracefully!")


birds = [Sparrow(), Penguin(), Bird()]

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("This instrument plays a sound")


class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar!")


class Piano(Instrument):
    def play(self):
        print("Playing the piano keys!")


instruments = [Guitar(), Piano(), Instrument()]

for inst in instruments:
    inst.play()

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):

        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate



class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %% [markdown]
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#
#     @abstractmethod
#     def sound(self):
#         pass
#
#
#
# class Cow(Animal):
#     def sound(self):
#         print("Moo!")
#
#
# class Sheep(Animal):
#     def sound(self):
#         print("Baa!")

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price



class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
